# %%
# !pip install torch torchvision torchaudio
# !pip install ultralytics  # for YOLOv8
# !pip install opencv-python
# !pip install matplotlib
# !pip install opencv-python ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 904.4/904.4 kB 15.7 MB/s eta 0:00:00
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from ultralytics import YOLO
from google.colab import drive

# Mount Google Drive
drive.mount('/content/drive')

# Load a model
model = YOLO("yolov8n.yaml")  # build a new model from scratch
model = YOLO("yolov8n.pt")  # load a pretrained model (recommended for training)

# Update the data path to point to your dataset in Google Drive
# Make sure to replace '/content/drive/MyDrive/your_dataset_path/data.yaml' with the actual path
results = model.train(data="/content/drive/MyDrive/Shop/data.yaml", epochs=20)
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# ...
# 100%|██████████| 6.25M/6.25M [00:00<00:00, 74.7MB/s]
# Ultralytics 8.3.56 🚀 Python-3.10.12 torch-2.5.1+cpu CPU (Intel Xeon 2.00GHz)
# ...

# %%
from google.colab import drive

# Mount Google Drive
drive.mount('/content/drive')

# Path to the trained model
trained_model_path = "/content/runs/detect/train/weights/best.pt"

# Destination path in Google Drive
destination_path = "/content/drive/MyDrive/Main_shop/trained_model/best.pt"

# Create destination folder and copy the trained model
# !mkdir -p "/content/drive/MyDrive/Main_shop/trained_model"  # Ensure the folder exists
# !cp {trained_model_path} {destination_path}  # Copy the model to Google Drive

print(f"Trained model saved to Google Drive at: {destination_path}")

# %%
from google.colab import drive
from google.colab.patches import cv2_imshow
import cv2

# Mount Google Drive
drive.mount('/content/drive')

# Specify the path to the video on Google Drive
video_path = "/content/drive/My Drive/shop.mp4"

# Function to process video and capture exactly 10 evenly spaced frames
def process_video(video_path, num_frames=10):
    cap = cv2.VideoCapture(video_path)
    if not cap.isOpened():
        print("Error: Could not open video.")
        return

    # Get the total number of frames in the video
    total_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))

    # Calculate the interval to capture 10 evenly spaced frames
    frame_interval = total_frames // num_frames

    # Loop through the video and capture frames at the calculated intervals
    for i in range(num_frames):
        # Set the frame position to the correct interval
        cap.set(cv2.CAP_PROP_POS_FRAMES, i * frame_interval)

        # Read the frame at the current position
        ret, frame = cap.read()
        if not ret:
            print(f"Error reading frame at position {i * frame_interval}")
            continue

        # Analyze the frame using YOLO
        results = model(frame)  # Assuming `model` is your YOLO model
        annotated_frame = results[0].plot()  # Get annotated frame

        # Use cv2_imshow() to display the frame in Colab
        cv2_imshow(annotated_frame)

    cap.release()

# Example: Load your YOLO model (replace this with your actual model loading code)
from ultralytics import YOLO
model = YOLO("/content/drive/My Drive/Main_shop/trained_model/best.pt")  # Use your YOLO model file

# Process the video and display exactly 10 evenly spaced frames
process_video(video_path, num_frames=10)
# Out:
# Output hidden; open in https://colab.research.google.com to view.
